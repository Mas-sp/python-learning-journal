# %% [markdown]
# <a href="https://colab.research.google.com/github/Mas-sp/python-learning-journal/blob/main/HW2_Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework: Introduction to Python
#
# In this homework assignment, you'll practice what you've learned so far: variables, types, operators, errors, and print statements. Complete each part and submit your notebook when you're done.
#
# **Instructions:**
# - Write your code in the provided cells.
# - Run each cell to check your results.
# - Submit your completed notebook by the due date.

# %% [markdown]
# ## Part 1: Variables and Types
#
# ### Exercise 1
# Create variables of the following types: `int`, `float`, and `str`. Assign any values you like to them and print each one.

# %%
myInt = 7
myFloat = 7.0
myString = "seven"

print(myInt)
print(myFloat)
print(myString)

print(type(myInt))
print(type(myFloat))
print(type(myString))
# Out:
# 7
# 7.0
# seven
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ### Exercise 2
# The following code contains errors. Identify and correct them.

# %%
# The code below has errors. Fix them.
my_number = 10
my_float = 5.0

my_number = float(my_number)

result = (my_number + my_float)
print("The result is:", (result))

# The code was trying to do addition with strings and concatantation, i changed the data type to float and adjusted the formula for that.
# Out:
# The result is: 15.0

# %% [markdown]
# ## Part 2: Operators
#
# ### Exercise 3
# Perform the following arithmetic operations and print the results:
# 1. Addition of two numbers.
# 2. Subtraction of one number from another.
# 3. Multiplication of two numbers.
# 4. Division of one number by another.

# %%
four_two = 4 + 2
print(four_two)

two_four = 2 - 4
print(two_four)

five_squared = 5 * 5
print(five_squared)

ten_halved = 10 / 2
print(ten_halved)
# Out:
# 6
# -2
# 25
# 5.0

# %% [markdown]
# ### Exercise 4
# Use comparison and logical operators to evaluate the following expressions and print the results:
# 1. Is 10 greater than 5?
# 2. Is 3 less than or equal to 3?
# 3. Is 7 equal to 8?
# 4. Is 5 greater than 3 and 2 less than 4?

# %%
print(("10 is greater than 5"),{10 >5})
print(("3 is greater than or equal to 3"),{3<=3})
print(("7 is equal to 8"),{7==8})
print(("5 is great than 3 & 2 is less than 4"),{5>3 & 2<4})
# Out:
# 10 is greater than 5 {True}
# 3 is greater than or equal to 3 {True}
# 7 is equal to 8 {False}
# 5 is great than 3 & 2 is less than 4 {True}

# %% [markdown]
# ## Part 3: Errors and Debugging
#
# ### Exercise 5
# The following code contains syntax and runtime errors. Identify and correct them.

# %%
# The code below has errors. Fix them.
myVariable = "This is my first string"
remove = " first"
finalString = myVariable.replace(" first", "")
print(finalString)

#variables had spaces
#"2remove" had an undefined decimal causing errors
#it was trying to subtract a string from another string, instead i used the replace command.
# Out:
# This is my string

# %% [markdown]
# ## Part 4: Print Statements
#
# ### Exercise 6
# Use print statements to display the following:
# 1. A string that says "Hello, World!"
# 2. A formatted string that includes the values of two variables.

# %%
print("Hello, World!")
variable1A = "horse"
variable1B = "shotgun!"

print("i love", (variable1A), "and also", (variable1B))
# Out:
# Hello, World!
# i love horse and also shotgun!

# %% [markdown]
# ### Exercise 7
# Print multiple variables each on their own line using a **single** print statement.

# %%
a1 = 1
a2 = 2
print(f"{a1}\n{a2}")
# Out:
# 1
# 2

# %% [markdown]
# ## Conclusion
#
# Reflect on what you've learned in this homework. What parts were easy for you? Which ones were challenging? Write a few sentences below.

# %% [markdown]
# Part 1 was pretty straightforward and easy and so was Exercise #3. Exercise 4 i was helped by a classmate, they just reminded me that i needed curly brackets and a comma instead of regular parenthesis. I struggled with exercise 5 for a while but ended up googling how to alter strings and then after i discovered the .replace fuction it was easy. Exercise 6 was easy, took me one attempt. Exercise 7 i had to ask about the new line fuction but other than that it wasn't difficult.
