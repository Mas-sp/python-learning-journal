# %% [markdown]
# <a href="https://colab.research.google.com/github/Mas-sp/python-learning-journal/blob/main/LabWeek2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kilometers = 97

constant = 0.621371

miles = kilometers * constant

print(f"{kilometers} kilometers is equal to {miles} miles.")
# Out:
# 97 kilometers is equal to 60.272987 miles.

# %%
celcius = 54

constant = 1.8

farenhieght = celcius * constant + 32

print(f"{celcius} celcius is equal to {farenhieght} farenhieght.")
# Out:
# 54 celcius is equal to 129.2 farenhieght.

# %%
valueDecimal = (1 * 2**8) + (0 * 2**7) + (1 * 2**6) + (1 * 2**5) + (0 * 2**4) + (1 * 2**3) + (0 * 2**2) + (0 * 2**1) + (0 * 2**0)
print(valueDecimal)
# Out:
# 360
